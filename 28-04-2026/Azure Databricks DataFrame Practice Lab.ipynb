# %%
data = [
    (101,"Olivia Bennett","London","Engineering",92000,5),
    (102,"Ethan Walker","New York","Marketing",75000,4),
    (103,"Sophia Turner","Toronto","Finance",88000,6),
    (104,"Liam Carter","Sydney","Engineering",97000,7),
    (105,"Mia Collins","Berlin","HR",69000,3),
    (106,"Noah Parker","Paris","Marketing",72000,4),
    (107,"Ava Reed","Tokyo","Finance",91000,6),
    (108,"Lucas Hayes","Madrid","Engineering",85000,5),
    (109,"Isabella Cruz","Rome","Finance",93000,8),
    (110,"Mason Gray","Chicago","Engineering",89000,6),
    (111,"Charlotte Fox","Dublin","HR",67000,3),
    (112,"Benjamin Stone","Boston","Marketing",76000,4),
    (113,"Amelia Knight","Amsterdam","Engineering",94000,7),
    (114,"James Holt","San Francisco","Finance",99000,9),
    (115,"Harper Lane","Melbourne","HR",64000,2),
    (116,"Alexander West","Seattle","Engineering",96000,7),
    (117,"Evelyn Scott","Vancouver","Marketing",74000,4),
    (118,"Henry Brooks","Zurich","Finance",97000,8),
    (119,"Ella Simmons","Stockholm","Engineering",88000,6),
    (120,"Daniel Ward","Singapore","Marketing",77000,5)
]
columns = ["emp_id","name","city","department","salary","experience"]
df = spark.createDataFrame(data, columns)

# %% [markdown]
# Section 1 — Basic DataFrame Exploration

# %%
#1
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#2
df.printSchema()
# Out:
# root
#  |-- emp_id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- department: string (nullable = true)
#  |-- salary: long (nullable = true)
#  |-- experience: long (nullable = true)

# %%
#3
df.count()
# Out:
# 20

# %%
#4
display(df.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#5
display(df.tail(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#6
print(df.columns)
# Out:
# ['emp_id', 'name', 'city', 'department', 'salary', 'experience']

# %%
#7
display(df.select("name","salary"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#8
display(df.select("name","department","experience"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#9
display(df.select("department").distinct())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th></tr></thead><tbody><tr><td>Engineering</td></tr><tr><td>Marketing</td></tr><tr><td>Finance</td></tr><tr><td>HR</td></tr></tbody></table></div>

# %%
# 10
display(df.select("city").distinct())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th></tr></thead><tbody><tr><td>London</td></tr><tr><td>New York</td></tr><tr><td>Toronto</td></tr><tr><td>Sydney</td></tr><tr><td>Berlin</td></tr><tr><td>Paris</td></tr><tr><td>Tokyo</td></tr><tr><td>Madrid</td></tr><tr><td>Rome</td></tr><tr><td>Chicago</td></tr><tr><td>Dublin</td></tr><tr><td>Boston</td></tr><tr><td>Amsterdam</td></tr><tr><td>San Francisco</td></tr><tr><td>Melbourne</td></tr><tr><td>Seattle</td></tr><tr><td>Vancouver</td></tr><tr><td>Zurich</td></tr><tr><td>Stockholm</td></tr><tr><td>Singapore</td></tr></tbody></table></div>

# %% [markdown]
# Section 2 — Filtering Data

# %%
#11
display(df.filter(df.salary > 90000))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#12
display(df.filter(df.department == "Engineering"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#13
display(df.filter(df.department == "Marketing"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#14
display(df.filter(df.experience > 6))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#15
display(df.filter(df.salary < 70000))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>city</th><th>department</th><th>salary</th><th>experience</th></tr></thead><tbody><tr><td>105</td><td>Mia Collins</td><td>Berlin</td><td>HR</td><td>69000</td><td>3</td></tr><tr><td>111</td><td>Charlotte Fox</td><td>Dublin</td><td>HR</td><td>67000</td><td>3</td></tr><tr><td>115</td><td>Harper Lane</td><td>Melbourne</td><td>HR</td><td>64000</td><td>2</td></tr></tbody></table></div>

# %%
#16
display(df.filter(df.city == "London"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>city</th><th>department</th><th>salary</th><th>experience</th></tr></thead><tbody><tr><td>101</td><td>Olivia Bennett</td><td>London</td><td>Engineering</td><td>92000</td><td>5</td></tr></tbody></table></div>

# %%
#17
display(df.filter((df.department == "Finance") & (df.salary > 90000)))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>city</th><th>department</th><th>salary</th><th>experience</th></tr></thead><tbody><tr><td>107</td><td>Ava Reed</td><td>Tokyo</td><td>Finance</td><td>91000</td><td>6</td></tr><tr><td>109</td><td>Isabella Cruz</td><td>Rome</td><td>Finance</td><td>93000</td><td>8</td></tr><tr><td>114</td><td>James Holt</td><td>San Francisco</td><td>Finance</td><td>99000</td><td>9</td></tr><tr><td>118</td><td>Henry Brooks</td><td>Zurich</td><td>Finance</td><td>97000</td><td>8</td></tr></tbody></table></div>

# %%
#18
display(df.filter((df.department == "Engineering") & (df.experience > 5)))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#19
display(df.filter((df.salary >= 85000) & (df.salary <= 95000)))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#20
display(df.filter(df.experience < 4))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>city</th><th>department</th><th>salary</th><th>experience</th></tr></thead><tbody><tr><td>105</td><td>Mia Collins</td><td>Berlin</td><td>HR</td><td>69000</td><td>3</td></tr><tr><td>111</td><td>Charlotte Fox</td><td>Dublin</td><td>HR</td><td>67000</td><td>3</td></tr><tr><td>115</td><td>Harper Lane</td><td>Melbourne</td><td>HR</td><td>64000</td><td>2</td></tr></tbody></table></div>

# %% [markdown]
# Section 3 — Sorting

# %%
#21
display(df.orderBy("salary"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#22
display(df.orderBy(df.salary.desc()))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#23
display(df.orderBy("experience"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#24
display(df.orderBy(df.experience.desc()))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#25
display(df.orderBy("department"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#26
display(df.orderBy("city"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#27
display(df.orderBy("department","salary"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#28
display(df.orderBy(df.salary.desc()).limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#29
display(df.orderBy("salary").limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>city</th><th>department</th><th>salary</th><th>experience</th></tr></thead><tbody><tr><td>115</td><td>Harper Lane</td><td>Melbourne</td><td>HR</td><td>64000</td><td>2</td></tr><tr><td>111</td><td>Charlotte Fox</td><td>Dublin</td><td>HR</td><td>67000</td><td>3</td></tr><tr><td>105</td><td>Mia Collins</td><td>Berlin</td><td>HR</td><td>69000</td><td>3</td></tr><tr><td>106</td><td>Noah Parker</td><td>Paris</td><td>Marketing</td><td>72000</td><td>4</td></tr><tr><td>117</td><td>Evelyn Scott</td><td>Vancouver</td><td>Marketing</td><td>74000</td><td>4</td></tr></tbody></table></div>

# %%
#30
display(df.orderBy(df.experience.desc()).limit(3))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>city</th><th>department</th><th>salary</th><th>experience</th></tr></thead><tbody><tr><td>114</td><td>James Holt</td><td>San Francisco</td><td>Finance</td><td>99000</td><td>9</td></tr><tr><td>109</td><td>Isabella Cruz</td><td>Rome</td><td>Finance</td><td>93000</td><td>8</td></tr><tr><td>118</td><td>Henry Brooks</td><td>Zurich</td><td>Finance</td><td>97000</td><td>8</td></tr></tbody></table></div>

# %% [markdown]
# Section 4 — Column Transformations

# %%
#31
from pyspark.sql.functions import lit, col
display(df.withColumn("annual_salary", col("salary") * 12))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#32
display(df.withColumn("salary_in_thousands", col("salary") / 1000))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#33
display(df.withColumn("experience_double", col("experience") * 2))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#34
display(df.withColumn("company", lit("GlobalTech")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#35
display(df.withColumn("salary_after_bonus", col("salary") + 5000))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#36
display(df.withColumn("salary_after_tax", col("salary") * 0.9))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#37
display(df.withColumn("experience_next_year", col("experience") + 1))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#38
display(df.withColumn("salary_per_year_of_experience", col("salary") / col("experience")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#39
display(df.withColumnRenamed("salary","monthly_salary"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#40
df_new = df.withColumn("experience_double", col("experience") * 2)
display(df_new.drop("experience_double"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# Section 5 — Aggregations

# %%
#41
from pyspark.sql.functions import sum, avg, max, min, count
display(df.agg(sum("salary").alias("total_salary")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_salary</th></tr></thead><tbody><tr><td>1683000</td></tr></tbody></table></div>

# %%
#42
display(df.agg(avg("salary").alias("avg_salary")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>avg_salary</th></tr></thead><tbody><tr><td>84150.0</td></tr></tbody></table></div>

# %%
#43
display(df.agg(max("salary").alias("max_salary")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>max_salary</th></tr></thead><tbody><tr><td>99000</td></tr></tbody></table></div>

# %%
#44
display(df.agg(min("salary").alias("min_salary")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>min_salary</th></tr></thead><tbody><tr><td>64000</td></tr></tbody></table></div>

# %%
#45
display(df.agg(count("emp_id").alias("total_employees")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_employees</th></tr></thead><tbody><tr><td>20</td></tr></tbody></table></div>

# %%
#46
display(df.groupBy("department").count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>count</th></tr></thead><tbody><tr><td>Engineering</td><td>7</td></tr><tr><td>Marketing</td><td>5</td></tr><tr><td>Finance</td><td>5</td></tr><tr><td>HR</td><td>3</td></tr></tbody></table></div>

# %%
#47
display(df.groupBy("department").agg(avg("salary").alias("avg_salary")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>avg_salary</th></tr></thead><tbody><tr><td>Engineering</td><td>91571.42857142857</td></tr><tr><td>Marketing</td><td>74800.0</td></tr><tr><td>Finance</td><td>93600.0</td></tr><tr><td>HR</td><td>66666.66666666667</td></tr></tbody></table></div>

# %%
#48
display(df.groupBy("department").agg(max("salary").alias("max_salary")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>max_salary</th></tr></thead><tbody><tr><td>Engineering</td><td>97000</td></tr><tr><td>Marketing</td><td>77000</td></tr><tr><td>Finance</td><td>99000</td></tr><tr><td>HR</td><td>69000</td></tr></tbody></table></div>

# %%
#49
display(df.groupBy("department").agg(min("salary").alias("min_salary")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>min_salary</th></tr></thead><tbody><tr><td>Engineering</td><td>85000</td></tr><tr><td>Marketing</td><td>72000</td></tr><tr><td>Finance</td><td>88000</td></tr><tr><td>HR</td><td>64000</td></tr></tbody></table></div>

# %%
#50
display(df.groupBy("department").agg(sum("salary").alias("total_salary")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>total_salary</th></tr></thead><tbody><tr><td>Engineering</td><td>641000</td></tr><tr><td>Marketing</td><td>374000</td></tr><tr><td>Finance</td><td>468000</td></tr><tr><td>HR</td><td>200000</td></tr></tbody></table></div>

# %% [markdown]
# Section 6 — GroupBy

# %%
#51
display(df.groupBy("city").count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#52
display(df.groupBy("department").agg(avg("experience").alias("avg_experience")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>avg_experience</th></tr></thead><tbody><tr><td>Engineering</td><td>6.142857142857143</td></tr><tr><td>Marketing</td><td>4.2</td></tr><tr><td>Finance</td><td>7.4</td></tr><tr><td>HR</td><td>2.6666666666666665</td></tr></tbody></table></div>

# %%
#53
display(df.groupBy("department").agg(max("experience").alias("max_experience")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>max_experience</th></tr></thead><tbody><tr><td>Engineering</td><td>7</td></tr><tr><td>Marketing</td><td>5</td></tr><tr><td>Finance</td><td>9</td></tr><tr><td>HR</td><td>3</td></tr></tbody></table></div>

# %%
#54
display(df.groupBy("city").agg(sum("salary").alias("total_salary")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#55
display(df.groupBy("city").agg(avg("salary").alias("avg_salary")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#56
display(df.groupBy("city").agg(max("salary").alias("highest_salary")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#57
display(df.groupBy("city").agg(min("salary").alias("lowest_salary")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#58
display(df.groupBy("city").agg(avg("experience").alias("avg_experience")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#59
display(df.groupBy("department","city").count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#60
display(df.groupBy("department","city").agg(sum("salary").alias("total_salary")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# Section 7 — Data Cleaning

# %%
#61
from pyspark.sql.functions import isnan, when, count
df = df.dropDuplicates()
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#62
display(df.select([count(when(col(c).isNull(), c)).alias(c) for c in df.columns]))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>city</th><th>department</th><th>salary</th><th>experience</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
#63
display(df.fillna({"salary": 0}))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#64
display(df.dropna(subset=["department"]))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#65
from pyspark.sql.functions import round as spark_round
avg_exp = df.agg(avg("experience")).first()[0]
display(df.fillna({"experience": avg_exp}))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#66
print(df.count())
# Out:
# 20

# %%
#67
display(df.fillna({"department": "Unknown"}))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#68
display(df.filter(df.salary >= 60000))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#69
display(df.filter(df.experience >= 2))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#70
df_cleaned = df.dropDuplicates().dropna(subset=["department"]).filter(df.salary >= 60000).filter(df.experience >= 2)
display(df_cleaned)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
